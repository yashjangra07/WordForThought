# %% [markdown]
# <a href="https://colab.research.google.com/github/riya913/WordForThought/blob/main/Week%200/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Cardiovascular_Disease_Dataset.csv')
#reads the csv file and stores it in a data frame(define in the pandas library)

# %%
dictionary = {'col':[4,2,3], 'col2':[4,7,6], 'col3':[7,10,9]}

# %%
dictionarydf = pd.DataFrame.from_dict(dictionary)
#it creats a new datafram which stores the dictionary made above

# %%
df.head()
#shows top 5 rows (row indexing starts from 0)
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
df.head(10)
#shows 10 rows from the tops
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
# 5     148462   24       1          1        173                0
# 6     168686   79       1          2        130              240
# 7     170498   52       1          0        127              345
# 8     188225   62       1          0        121              357
# 9     192523   61       0          0        190              181
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# ...

# %%
dictionarydf.head()
# Out:
#    col  col2  col3
# 0    4     4     7
# 1    2     7    10
# 2    3     6     9

# %%
df.tail(15)
#Shows the last 15 rows
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 985    9837223   58       1          0        150              429
# 986    9846037   33       1          2        120              416
# 987    9856541   30       1          2        169              316
# 988    9870657   74       1          0        136              279
# 989    9876043   56       0          0        142              230
# 990    9888918   63       0          1        196              367
# 991    9896438   24       1          0        170              354
# 992    9911700   77       0          0        183              298
# 993    9921653   25       0          1        197                0
# 994    9937998   62       1          1        125              342
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# ...

# %%
df.columns
#lists all the columns of the dataset
# Out:
# Index(['patientid', 'age', 'gender', 'chestpain', 'restingBP',
#        'serumcholestrol', 'fastingbloodsugar', 'restingrelectro',
#        'maxheartrate', 'exerciseangia', 'oldpeak', 'slope', 'noofmajorvessels',
#        'target'],
#       dtype='object')

# %%
df.dtypes
#shows the data types of each feature or column name
# Out:
# patientid              int64
# age                    int64
# gender                 int64
# chestpain              int64
# restingBP              int64
# serumcholestrol        int64
# fastingbloodsugar      int64
# restingrelectro        int64
# maxheartrate           int64
# exerciseangia          int64
# oldpeak              float64
# slope                  int64
# noofmajorvessels       int64
# target                 int64
# dtype: object

# %%
df.describe()
#describes the data through statistics
# Out:
#           patientid         age       gender    chestpain    restingBP  \
# count  1.000000e+03  1000.00000  1000.000000  1000.000000  1000.000000
# mean   5.048704e+06    49.24200     0.765000     0.980000   151.747000
# std    2.895905e+06    17.86473     0.424211     0.953157    29.965228
# min    1.033680e+05    20.00000     0.000000     0.000000    94.000000
# 25%    2.536440e+06    34.00000     1.000000     0.000000   129.000000
# 50%    4.952508e+06    49.00000     1.000000     1.000000   147.000000
# 75%    7.681877e+06    64.25000     1.000000     2.000000   181.000000
# max    9.990855e+06    80.00000     1.000000     3.000000   200.000000
#
#        serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count      1000.000000        1000.000000      1000.000000   1000.000000
# mean        311.447000           0.296000         0.748000    145.477000
# std         132.443801           0.456719         0.770123     34.190268
# ...

# %%
df.describe(include='object')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e9c15d751cf5> in <cell line: 1>()
# ----> 1 df.describe(include='object')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   10817         max            NaN      3.0
#   10818         """
# > 10819         return describe_ndframe(
#   10820             obj=self,
#   10821             include=include,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      92         )
#      93
# ---> 94     result = describer.describe(percentiles=percentiles)
#      95     return cast(NDFrameT, result)
#      96
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/methods/describe.py in describe(self, percentiles)
#     168
# ...

# %%
df.age
#should not have a space in the column name
#if some have space in them then use the below command
# df['column name'], example:- df['cricket score']
# Out:
# 0      53
# 1      40
# 2      49
# 3      43
# 4      31
#        ..
# 995    48
# 996    47
# 997    69
# 998    45
# 999    25
# Name: age, Length: 1000, dtype: int64

# %%
df[['age', 'patientid']]
#From taking multiple columns from the dataset
# Out:
#      age  patientid
# 0     53     103368
# 1     40     119250
# 2     49     119372
# 3     43     132514
# 4     31     146211
# ..   ...        ...
# 995   48    9949544
# 996   47    9953423
# 997   69    9965859
# 998   45    9988507
# 999   25    9990855
#
# [1000 rows x 2 columns]

# %%
df.age.unique()
#gives the unique values present in that particular column
# Out:
# array([53, 40, 49, 43, 31, 24, 79, 52, 62, 61, 59, 58, 27, 32, 42, 65, 35,
#        39, 72, 71, 46, 23, 20, 78, 29, 75, 25, 48, 37, 66, 22, 26, 51, 77,
#        28, 54, 41, 63, 73, 68, 34, 38, 55, 69, 21, 57, 60, 74, 44, 36, 80,
#        70, 30, 33, 76, 67, 45, 64, 47, 50, 56])

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
df[df['chestpain']== 2]
#df[df['International plan']=='No']
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 2       119372   49       1          2        133              142
# 6       168686   79       1          2        130              240
# 11      208877   58       1          2        192              409
# 15      235344   32       1          2        188                0
# ..         ...  ...     ...        ...        ...              ...
# 973    9694810   25       1          2        145              488
# 980    9782088   46       1          2        147                0
# 986    9846037   33       1          2        120              416
# 987    9856541   30       1          2        169              316
# 995    9949544   48       1          2        139              349
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# ...

# %%
df[(df['chestpain']== 2) & (df['fastingbloodsugar']== 0)]
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 2       119372   49       1          2        133              142
# 6       168686   79       1          2        130              240
# 15      235344   32       1          2        188                0
# 18      247055   59       1          2        182              177
# ..         ...  ...     ...        ...        ...              ...
# 972    9694500   54       1          2        176                0
# 980    9782088   46       1          2        147                0
# 986    9846037   33       1          2        120              416
# 987    9856541   30       1          2        169              316
# 995    9949544   48       1          2        139              349
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# ...

# %%
df.iloc[10]
#this gets the 11th row from the dataset
#for taking 11th row why did we use 10???
# Out:
# patientid            201030.0
# age                      59.0
# gender                    0.0
# chestpain                 1.0
# restingBP               190.0
# serumcholestrol         529.0
# fastingbloodsugar         1.0
# restingrelectro           1.0
# maxheartrate            151.0
# exerciseangia             1.0
# oldpeak                   3.2
# slope                     2.0
# noofmajorvessels          2.0
# target                    1.0
# Name: 10, dtype: float64

# %%
df.iloc[10,0]
#df.iloc[row,column]
# Out:
# 201030

# %%
df.iloc[10,-1]
# Out:
# 1

# %%
df.iloc[10,-2]
# Out:
# 2

# %%
df.iloc[22:33]
#takes everything from row 23(included) and 34(not included)
# Out:
#     patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 22     327110   24       0          0        136              164
# 23     335359   59       1          2        156              223
# 24     384606   40       1          1        191              349
# 25     390931   71       1          1        101              352
# 26     390988   46       1          0        198              253
# 27     407924   42       1          0        157                0
# 28     417218   72       0          2        126              478
# 29     422067   49       0          1        192              521
# 30     448075   23       0          0         97              175
# 31     463851   20       1          0        199              248
# 32     478864   78       0          0        186              404
#
#     fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 22                  0                0            91              1      1.8
# ...

# %%
ageindexing = df.copy()
#makes a copy of original dataset which is named as age
ageindexing.set_index('age', inplace=True)
#it makes a separate index with age
#inplace==True does the changes in that data frame directly without making a copy

# %%
df.head()
#above thing didn't affect the original dataset. why???
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
ageindexing.head()
# Out:
#      patientid  gender  chestpain  restingBP  serumcholestrol  \
# age
# 53      103368       1          2        171                0
# 40      119250       1          0         94              229
# 49      119372       1          2        133              142
# 43      132514       1          0        138              295
# 31      146211       1          1        199                0
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# age
# 53                   0                1           147              0      5.3
# 40                   0                1           115              0      3.7
# 49                   0                0           202              1      5.0
# 43                   1                1           153              0      3.2
# 31                   0                2           136              0      5.3
#
#      slope  noofmajorvessels  target
# age
# 53       3                 3       1
# ...

# %%
ageindexing.loc[53]
#gives every row in which age == 53
#if dtype = object then use columnname.loc['in single quotes']
# Out:
#      patientid  gender  chestpain  restingBP  serumcholestrol  \
# age
# 53      103368       1          2        171                0
# 53      579647       1          2        123              326
# 53     2025910       1          2        167              373
# 53     2893921       0          2        195              335
# 53     3389865       1          2         96              430
# 53     3966249       1          0        125              214
# 53     4111303       1          1        101              354
# 53     5858219       0          3        135              435
# 53     6614078       0          2        125              430
# 53     8226331       0          1        195              493
# 53     8462428       1          2        136              214
# 53     9732542       1          1        184              368
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# age
# ...

# %%
df.isnull().sum()
#in pandas null values == na(not available)
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df1=df.copy()
df1.dropna(axis=0, inplace=False)
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# ...

# %%
df.dropna(axis=0, inplace=True)
#drops all the rows with missing values

# %%
df.isnull().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df.drop('gender==0', axis=0)
#axis = 1 for columns and axis = 0 for rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-a8ce686c1960> in <cell line: 1>()
# ----> 1 df.drop('gender==0', axis=0)
#       2 #axis = 1 for columns and axis = 0 for rows
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
df['Newcolumn'] = df['maxheartrate'] + df['restingBP']

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target  Newcolumn
# 0      3                 3       1        318
# ...

# %%
df['Newcolumn'] = 561

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target  Newcolumn
# 0      3                 3       1        561
# ...

# %%
df.iloc[1,-1] = 100

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1         High              0      5.3
# 1                  0                1       Normal              0      3.7
# 2                  0                0         High              1      5.0
# 3                  1                1         High              0      3.2
# 4                  0                2         High              0      5.3
#
#    slope  noofmajorvessels  target  Newcolumn maxheartrateLevel
# ...

# %%
df.maxheartrate
# Out:
# 0        High
# 1      Normal
# 2        High
# 3        High
# 4        High
#         ...
# 995      High
# 996    Normal
# 997      High
# 998    Normal
# 999      High
# Name: maxheartrate, Length: 765, dtype: object

# %%
df['maxheartratelevel'] = df['maxheartrate'].apply(lambda x: 'High' if x>135 else 'Normal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-eb61b67695af> in <cell line: 1>()
# ----> 1 df['maxheartratelevel'] = df['maxheartrate'].apply(lambda x: 'High' if x>135 else 'Normal')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1074             else:
# ...

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1         High              0      5.3
# 1                  0                1       Normal              0      3.7
# 2                  0                0         High              1      5.0
# 3                  1                1         High              0      3.2
# 4                  0                2         High              0      5.3
#
#    slope  noofmajorvessels  target  Newcolumn maxheartrateLevel
# ...

# %%
df[df['maxheartrate'] > 135].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-79a6304c02f6> in <cell line: 1>()
# ----> 1 df[df['maxheartrate'] > 135].head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
#    6095         with np.errstate(all="ignore"):
# ...

# %%
df.to_csv('cleandata_cardio_risk_output.csv')

# %%
del df
